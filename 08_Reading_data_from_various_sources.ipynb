# %% [markdown]
# <a href="https://colab.research.google.com/github/noctxrne/ICT-Notes/blob/main/08_Reading_data_from_various_sources.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
employees =pd.read_excel('/content/employee.xlsx',header=1)
employees
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing 2018-03-12   72000       True
# 1  E1002   Ahmed Hassan  Engineering 2019-07-23   85000       True
# 2  E1003    Priya Singh           HR 2020-01-15   60000      False
# 3  E1004         Li Wei      Finance 2017-11-30   79000       True
# 4  E1005  Carlos Mendes        Sales 2021-05-10   67000       True

# %%
#Reading data of Sheet2 of the the excel file path
employee2=pd.read_excel('/content/updated1_employee.xlsx',header=1,sheet_name='Sheet2')
employee2
# Out:
#   emp_id     name   department  hire_date  salary  full_time
# 0  E1001    Shaji    Marketing 2018-03-12   72000       True
# 1  E1002   nikhil  Engineering 2019-07-23   85000       True
# 2  E1003  RajuA10           HR 2020-01-15   60000      False
# 3  E1004   Shammi      Finance 2017-11-30   79000       True
# 4  E1005      A10        Sales 2021-05-10   67000       True

# %%
#Initialising Sheet2 as variable
employee2=pd.read_excel('/content/updated1_employee.xlsx',header=1,sheet_name=None)
employee2
# Out:
# {'Sheet1':   emp_id           name   department  hire_date  salary  full_time
#  0  E1001  Julia Roberts    Marketing 2018-03-12   72000       True
#  1  E1002   Ahmed Hassan  Engineering 2019-07-23   85000       True
#  2  E1003         Saketh           HR 2020-01-15   60000      False
#  3  E1004         Li Wei      Finance 2017-11-30   79000       True
#  4  E1005        Chandra        Sales 2021-05-10   67000       True,
#  'Sheet2':   emp_id     name   department  hire_date  salary  full_time
#  0  E1001    Shaji    Marketing 2018-03-12   72000       True
#  1  E1002   nikhil  Engineering 2019-07-23   85000       True
#  2  E1003  RajuA10           HR 2020-01-15   60000      False
#  3  E1004   Shammi      Finance 2017-11-30   79000       True
#  4  E1005      A10        Sales 2021-05-10   67000       True}

# %%
#Initialising Sheet1 as variable
employeeSheet1=employee2['Sheet1']
employeeSheet1
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing 2018-03-12   72000       True
# 1  E1002   Ahmed Hassan  Engineering 2019-07-23   85000       True
# 2  E1003         Saketh           HR 2020-01-15   60000      False
# 3  E1004         Li Wei      Finance 2017-11-30   79000       True
# 4  E1005        Chandra        Sales 2021-05-10   67000       True

# %%
employeeSheet2=employee2['Sheet2']
employeeSheet2
# Out:
#   emp_id     name   department  hire_date  salary  full_time
# 0  E1001    Shaji    Marketing 2018-03-12   72000       True
# 1  E1002   nikhil  Engineering 2019-07-23   85000       True
# 2  E1003  RajuA10           HR 2020-01-15   60000      False
# 3  E1004   Shammi      Finance 2017-11-30   79000       True
# 4  E1005      A10        Sales 2021-05-10   67000       True

# %%
#Concatenate two sheets (Sheet1 and Sheet2)
combined=pd.concat([employeeSheet1,employeeSheet2],ignore_index=True)
combined
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing 2018-03-12   72000       True
# 1  E1002   Ahmed Hassan  Engineering 2019-07-23   85000       True
# 2  E1003         Saketh           HR 2020-01-15   60000      False
# 3  E1004         Li Wei      Finance 2017-11-30   79000       True
# 4  E1005        Chandra        Sales 2021-05-10   67000       True
# 5  E1001          Shaji    Marketing 2018-03-12   72000       True
# 6  E1002         nikhil  Engineering 2019-07-23   85000       True
# 7  E1003        RajuA10           HR 2020-01-15   60000      False
# 8  E1004         Shammi      Finance 2017-11-30   79000       True
# 9  E1005            A10        Sales 2021-05-10   67000       True

# %%
#finding mean of a data of a particular column
combined[combined['full_time']==True]
# Out:
#   emp_id           name   department  hire_date  salary  full_time
# 0  E1001  Julia Roberts    Marketing 2018-03-12   72000       True
# 1  E1002   Ahmed Hassan  Engineering 2019-07-23   85000       True
# 3  E1004         Li Wei      Finance 2017-11-30   79000       True
# 4  E1005        Chandra        Sales 2021-05-10   67000       True
# 5  E1001          Shaji    Marketing 2018-03-12   72000       True
# 6  E1002         nikhil  Engineering 2019-07-23   85000       True
# 8  E1004         Shammi      Finance 2017-11-30   79000       True
# 9  E1005            A10        Sales 2021-05-10   67000       True

# %%
mean_value=combined['salary'].mean()
print(f"Mean is {mean_value}")
# Out:
# Mean is 72600.0

# %%
#creating aa new excel file from old file with a new name
combined.to_excel("employeeNew.xlsx")

# %%
#Reading a csv file called weather
df=pd.read_csv('/content/weather.csv',)
df
# Out:
#          date station_id  temperature_c  humidity_pct  wind_speed_kmh  \
# 0  2025-07-01      WS100           29.5            65            12.4
# 1  2025-07-01      WS101           31.2            58             8.7
# 2  2025-07-01      WS102           28.9            72             5.2
# 3  2025-07-02      WS100           30.1            63            14.0
# 4  2025-07-02      WS101           32.0            55            10.1
# 5  2025-07-02      WS102           29.5            70             6.0
# 6  2025-07-03      WS100           28.0            68            11.3
# 7  2025-07-03      WS101           29.8            60             9.5
# 8  2025-07-03      WS102           27.7            75             4.8
#
#    precip_mm
# 0        0.0
# 1        0.0
# 2        1.3
# 3        0.0
# 4        0.0
# 5        0.8
# 6        2.5
# 7        0.0
# 8        3.1

# %%
# listing items whose temperature >30
df[df['temperature_c']>30]
# Out:
#          date station_id  temperature_c  humidity_pct  wind_speed_kmh  \
# 1  2025-07-01      WS101           31.2            58             8.7
# 3  2025-07-02      WS100           30.1            63            14.0
# 4  2025-07-02      WS101           32.0            55            10.1
#
#    precip_mm
# 1        0.0
# 3        0.0
# 4        0.0

# %%
# listing items whose temperature >30 ..[using query]
df.query("temperature_c >30")
# Out:
#          date station_id  temperature_c  humidity_pct  wind_speed_kmh  \
# 1  2025-07-01      WS101           31.2            58             8.7
# 3  2025-07-02      WS100           30.1            63            14.0
# 4  2025-07-02      WS101           32.0            55            10.1
#
#    precip_mm
# 1        0.0
# 3        0.0
# 4        0.0

# %%
#grouping by the date and finding the respective means for it
df.groupby('date')['humidity_pct'].mean()
# Out:
# date
# 2025-07-01    65.000000
# 2025-07-02    62.666667
# 2025-07-03    67.666667
# Name: humidity_pct, dtype: float64

# %%
books=pd.read_xml('/content/library_catalog.xml')
books
# Out:
#              isbn                    title           author            genre  \
# 0  978-0143127550              The Martian        Andy Weir  Science Fiction
# 1  978-0553386790  Thinking, Fast and Slow  Daniel Kahneman       Psychology
# 2  978-0062316097            The Alchemist     Paulo Coelho          Fiction
#
#   publish_date  price
# 0   2014-10-28   9.99
# 1   2013-04-02  12.50
# 2   2014-04-15   8.99

# %%
books['genre'].unique()
# Out:
# array(['Science Fiction', 'Psychology', 'Fiction'], dtype=object)

# %%
df=pd.read_json('/content/movies.json')
df
# Out:
#   movie_id                     title  year                      genres  \
# 0    MV001                 Inception  2010            [Action, Sci‐Fi]
# 1    MV002           The Dark Knight  2008      [Action, Crime, Drama]
# 2    MV003              Interstellar  2014  [Adventure, Drama, Sci‐Fi]
# 3    MV004                The Matrix  1999            [Action, Sci‐Fi]
# 4    MV005                  Parasite  2019   [Comedy, Drama, Thriller]
# 5    MV006                 Gladiator  2000  [Action, Adventure, Drama]
# 6    MV007         Avengers: Endgame  2019  [Action, Adventure, Drama]
# 7    MV008  The Shawshank Redemption  1994                     [Drama]
# 8    MV009              Pulp Fiction  1994              [Crime, Drama]
# 9    MV010              Forrest Gump  1994            [Drama, Romance]
#
#    rating    votes
# 0     8.8  2100000
# 1     9.0  2300000
# 2     8.6  1500000
# 3     8.7  1700000
# 4     8.6   700000
# 5     8.5  1400000
# 6     8.4  1000000
# 7     9.3  2400000
# ...

# %%
# find max rating
df['rating'].max()
# Out:
# 9.3

# %%
#finding mean of each genre by first exploding by genre and then grouping it and finally finding mean
exp=df.explode('genres')
mean_value=exp.groupby("genres")['rating'].mean()
print(mean_value)
# Out:
# Mean:
# genres
# Action       8.6800
# Adventure    8.5000
# Comedy       8.6000
# Crime        8.9500
# Drama        8.7625
# Romance      8.8000
# Sci‐Fi       8.7000
# Thriller     8.6000
# Name: rating, dtype: float64

# %%
count=df.groupby("year")['year'].count()
print(count)
# Out:
# year
# 1994    3
# 1999    1
# 2000    1
# 2008    1
# 2010    1
# 2014    1
# 2019    2
# Name: year, dtype: int64

# %%
df=pd.read_html('/content/review.html')
df
# Out:
# [  review_id reviewer     restaurant  rating                         comment  \
#  0      R001    Alice  The Spice Hub     4.5   Great flavors but a bit loud.
#  1      R002      Bob    Sushi World     5.0    Fresh fish and perfect rice.
#  2      R003     Chen   Pasta Palace     4.0  Cozy place, generous portions.
#
#           date
#  0  2025-06-20
#  1  2025-06-22
#  2  2025-06-25  ]

# %%
df=pd.read_html('/content/review.html')[0]
df
# Out:
#   review_id reviewer     restaurant  rating                         comment  \
# 0      R001    Alice  The Spice Hub     4.5   Great flavors but a bit loud.
# 1      R002      Bob    Sushi World     5.0    Fresh fish and perfect rice.
# 2      R003     Chen   Pasta Palace     4.0  Cozy place, generous portions.
#
#          date
# 0  2025-06-20
# 1  2025-06-22
# 2  2025-06-25

# %%
df[df['rating'] > 4.5]
# Out:
#   review_id reviewer   restaurant  rating                       comment  \
# 1      R002      Bob  Sushi World     5.0  Fresh fish and perfect rice.
#
#          date
# 1  2025-06-22

# %%
import requests
url="https://disease.sh/v3/covid-19/countries"
response=requests.get(url)
data=response.json()
#data

covid_df=pd.DataFrame(data)
covid_df.head()
# Out:
#          updated      country  \
# 0  1757414676667  Afghanistan
# 1  1757414676659      Albania
# 2  1757414676663      Algeria
# 3  1757414676715      Andorra
# 4  1757414676689       Angola
#
#                                          countryInfo   cases  todayCases  \
# 0  {'_id': 4, 'iso2': 'AF', 'iso3': 'AFG', 'lat':...  234174           0
# 1  {'_id': 8, 'iso2': 'AL', 'iso3': 'ALB', 'lat':...  334863           0
# 2  {'_id': 12, 'iso2': 'DZ', 'iso3': 'DZA', 'lat'...  272010           0
# 3  {'_id': 20, 'iso2': 'AD', 'iso3': 'AND', 'lat'...   48015           0
# 4  {'_id': 24, 'iso2': 'AO', 'iso3': 'AGO', 'lat'...  107327           0
#
#    deaths  todayDeaths  recovered  todayRecovered  active  ...    tests  \
# 0    7996            0     211080               0   15098  ...  1390730
# 1    3605            0     330233               0    1025  ...  1941032
# 2    6881            0     183061               0   82068  ...   230960
# ...

# %%
covid=covid_df[['country','cases','deaths','oneDeathPerPeople']]
covid
# Out:
#                country   cases  deaths  oneDeathPerPeople
# 0          Afghanistan  234174    7996               5097
# 1              Albania  334863    3605                795
# 2              Algeria  272010    6881               6591
# 3              Andorra   48015     165                469
# 4               Angola  107327    1937              18083
# ..                 ...     ...     ...                ...
# 226  Wallis and Futuna    3550       8               1373
# 227     Western Sahara      10       1             626161
# 228              Yemen   11945    2159              14430
# 229             Zambia  349304    4069               4785
# 230           Zimbabwe  266359    5740               2671
#
# [231 rows x 4 columns]

# %%
covid.to_excel("new_covidData.xlsx")

# %%
#to read html page
tables=pd.read_html('https://www.runnersworld.com/races-places/a20823734/these-are-the-worlds-fastest-marathoners-and-marathon-courses/')
tables
# Out:
# [                             0            1          2               3
#  0                       Runner  Finish Time  Pace/Mile        Marathon
#  1        Kelvin Kiptum (Kenya)      2:00:35     4:36.0   Chicago, 2023
#  2       Eliud Kipchoge (Kenya)      2:01:09     4:37.2    Berlin, 2022
#  3   Kenenisa Bekele (Ethiopia)      2:01:41     4:38.5    Berlin, 2019
#  4       Sisay Lemma (Ethiopia)      2:01:48     4:38.7  Valencia, 2023
#  5       Sabastian Sawe (Kenya)      2:02:05     4:39.4  Valencia, 2024
#  6       Benson Kipruto (Kenya)      2:02:16     4:39.8     Tokyo, 2024
#  7     Deresa Geleta (Ethiopia)      2:02:38     4:40.6  Valencia, 2024
#  8           John Korir (Kenya)      2:02:44     4:40.8   Chicago, 2024
#  9    Birhanu Legese (Ethiopia)      2:02:48     4:41.0    Berlin, 2019
#  10  Mosinet Geremew (Ethiopia)      2:02:55     4:41.3    London, 2019,
#                                    0            1          2               3
# ...

# %%
#here everytime the column title repeats as data 93 rows
combin=pd.concat(tables)
combin
# Out:
#                                   0            1          2               3
# 0                            Runner  Finish Time  Pace/Mile        Marathon
# 1             Kelvin Kiptum (Kenya)      2:00:35     4:36.0   Chicago, 2023
# 2            Eliud Kipchoge (Kenya)      2:01:09     4:37.2    Berlin, 2022
# 3        Kenenisa Bekele (Ethiopia)      2:01:41     4:38.5    Berlin, 2019
# 4            Sisay Lemma (Ethiopia)      2:01:48     4:38.7  Valencia, 2023
# ..                              ...          ...        ...             ...
# 5   Paula Radcliffe (Great Britain)      2:17:18     5:14.2   Chicago, 2002
# 6   Paula Radcliffe (Great Britain)      2:15:25     5:09.9    London, 2003
# 7             Brigid Kosgei (Kenya)      2:14:04     5:06.8   Chicago, 2019
# 8          Tigist Assefa (Ethiopia)      2:11:53     5:01.8    Berlin, 2023
# 9          Ruth Chepngetich (Kenya)      2:09:56     4:47.4   Chicago, 2024
#
# [93 rows x 4 columns]

# %%
#corrected line of code by removing the ones with index 0
combin=pd.concat(tables)
ss=combin[combin.index!=0]
ss
# Out:
#                                   0        1       2               3
# 1             Kelvin Kiptum (Kenya)  2:00:35  4:36.0   Chicago, 2023
# 2            Eliud Kipchoge (Kenya)  2:01:09  4:37.2    Berlin, 2022
# 3        Kenenisa Bekele (Ethiopia)  2:01:41  4:38.5    Berlin, 2019
# 4            Sisay Lemma (Ethiopia)  2:01:48  4:38.7  Valencia, 2023
# 5            Sabastian Sawe (Kenya)  2:02:05  4:39.4  Valencia, 2024
# ..                              ...      ...     ...             ...
# 5   Paula Radcliffe (Great Britain)  2:17:18  5:14.2   Chicago, 2002
# 6   Paula Radcliffe (Great Britain)  2:15:25  5:09.9    London, 2003
# 7             Brigid Kosgei (Kenya)  2:14:04  5:06.8   Chicago, 2019
# 8          Tigist Assefa (Ethiopia)  2:11:53  5:01.8    Berlin, 2023
# 9          Ruth Chepngetich (Kenya)  2:09:56  4:47.4   Chicago, 2024
#
# [85 rows x 4 columns]

# %%
#same code as above but using for loop

# %%
url='https://api.spacexdata.com/v4/launches'
response=requests.get(url)
launch_data=response.json()
df1=pd.DataFrame(launch_data)
df1
# Out:
#                                               fairings  \
# 0    {'reused': False, 'recovery_attempt': False, '...
# 1    {'reused': False, 'recovery_attempt': False, '...
# 2    {'reused': False, 'recovery_attempt': False, '...
# 3    {'reused': False, 'recovery_attempt': False, '...
# 4    {'reused': False, 'recovery_attempt': False, '...
# ..                                                 ...
# 200  {'reused': None, 'recovery_attempt': None, 're...
# 201  {'reused': None, 'recovery_attempt': None, 're...
# 202  {'reused': None, 'recovery_attempt': None, 're...
# 203  {'reused': None, 'recovery_attempt': None, 're...
# 204  {'reused': None, 'recovery_attempt': None, 're...
#
#                                                  links  \
# 0    {'patch': {'small': 'https://images2.imgbox.co...
# 1    {'patch': {'small': 'https://images2.imgbox.co...
# 2    {'patch': {'small': 'https://images2.imgbox.co...
# 3    {'patch': {'small': 'https://images2.imgbox.co...
# ...

# %%
df2=df1[['name','date_utc','success','details','rocket','launchpad']]
df2
# Out:
#                        name                  date_utc success  \
# 0                 FalconSat  2006-03-24T22:30:00.000Z   False
# 1                   DemoSat  2007-03-21T01:10:00.000Z   False
# 2               Trailblazer  2008-08-03T03:34:00.000Z   False
# 3                    RatSat  2008-09-28T23:15:00.000Z    True
# 4                  RazakSat  2009-07-13T03:35:00.000Z    True
# ..                      ...                       ...     ...
# 200           Transporter-6  2022-12-01T00:00:00.000Z    None
# 201                   TTL-1  2022-12-01T00:00:00.000Z    None
# 202  WorldView Legion 1 & 2  2022-12-01T00:00:00.000Z    None
# 203     Viasat-3 & Arcturus  2022-12-01T00:00:00.000Z    None
# 204          O3b mPower 3.4  2022-12-01T00:00:00.000Z    None
#
#                                                details  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# ...

# %%
df2.rename(columns={'name':'mission_name','rocket':'rocket_id'},inplace=True)
# Out:
# /tmp/ipython-input-3171543063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename(columns={'name':'mission_name','rocket':'rocket_id'},inplace=True)

# %%
url ="https://api.spacexdata.com/v4/rockets"
response=requests.get(url)
data_launch=response.json()
dF1=pd.DataFrame(launch_data)
dF1
# Out:
#                                               fairings  \
# 0    {'reused': False, 'recovery_attempt': False, '...
# 1    {'reused': False, 'recovery_attempt': False, '...
# 2    {'reused': False, 'recovery_attempt': False, '...
# 3    {'reused': False, 'recovery_attempt': False, '...
# 4    {'reused': False, 'recovery_attempt': False, '...
# ..                                                 ...
# 200  {'reused': None, 'recovery_attempt': None, 're...
# 201  {'reused': None, 'recovery_attempt': None, 're...
# 202  {'reused': None, 'recovery_attempt': None, 're...
# 203  {'reused': None, 'recovery_attempt': None, 're...
# 204  {'reused': None, 'recovery_attempt': None, 're...
#
#                                                  links  \
# 0    {'patch': {'small': 'https://images2.imgbox.co...
# 1    {'patch': {'small': 'https://images2.imgbox.co...
# 2    {'patch': {'small': 'https://images2.imgbox.co...
# 3    {'patch': {'small': 'https://images2.imgbox.co...
# ...

# %%
final_data=df2.merge(dF1,left_on='rocket_id',right_on='id',how='left')
final_data
# Out:
#                mission_name                date_utc_x success_x  \
# 0                 FalconSat  2006-03-24T22:30:00.000Z     False
# 1                   DemoSat  2007-03-21T01:10:00.000Z     False
# 2               Trailblazer  2008-08-03T03:34:00.000Z     False
# 3                    RatSat  2008-09-28T23:15:00.000Z      True
# 4                  RazakSat  2009-07-13T03:35:00.000Z      True
# ..                      ...                       ...       ...
# 200           Transporter-6  2022-12-01T00:00:00.000Z      None
# 201                   TTL-1  2022-12-01T00:00:00.000Z      None
# 202  WorldView Legion 1 & 2  2022-12-01T00:00:00.000Z      None
# 203     Viasat-3 & Arcturus  2022-12-01T00:00:00.000Z      None
# 204          O3b mPower 3.4  2022-12-01T00:00:00.000Z      None
#
#                                              details_x  \
# 0     Engine failure at 33 seconds and loss of vehicle
# 1    Successful first stage burn and transition to ...
# ...
